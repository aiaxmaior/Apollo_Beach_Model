# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import glob as glob
import os as os

# %%
pwd
# Out:
# 'J:\\Brainstation\\Capstone Git\\Apollo_Beach_Model'

# %%
os.chdir('J:\\Brainstation\\Capstone Git\\Apollo_Beach_Model\\data\\PossibleDataSources\\Benthic Index\\Results')

# %%
# Read BENTHIC biodata spreadsheet
# Includes cleaned data: Shannon Diversity Index
benX = pd.read_csv('Benthic_BioDataSpreadsheet_AdjustedValues.csv',encoding='cp1252', low_memory=False)

# %%
# Initial data check
print(benX.shape)
print(benX.info())
benX.head()
# Out:
# (4787, 254)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4787 entries, 0 to 4786
# Columns: 254 entries, ProgramName to DomSpecies2RelAbund
# dtypes: float64(145), int64(2), object(107)
# memory usage: 9.3+ MB
# None
#           ProgramName                                     FundingProject  \
# 0  Benthic Monitoring  TBEP                                          ...
# 1  Benthic Monitoring  TBEP                                          ...
# 2  Benthic Monitoring  TBEP                                          ...
# 3  Benthic Monitoring  TBEP                                          ...
# 4  Benthic Monitoring  TBEP                                          ...
#
#   AreaAbbr          AreaName Hexagon  Year     SampleTime  StationID  \
# 0       HB  Hillsborough Bay    HB34  1993  9/14/93 11:33       2452
# 1       HB  Hillsborough Bay    HB26  1993  9/13/93 12:37       2453
# 2       HB  Hillsborough Bay    HB25  1993   9/9/93 12:17       2454
# 3       HB  Hillsborough Bay    HB25  1993   9/9/93 13:37       2455
# 4       HB  Hillsborough Bay    HB32  1993   9/9/93 15:00       2456
#
#   StationNumber   Latitude  ...  GeoMean_PEL_Ratio   TBBI   TBBICat  \
# 0        93HB03  27.874001  ...                NaN  68.84  Degraded
# 1        93HB04  27.875000  ...                NaN  57.33  Degraded
# 2        93HB05  27.867001  ...                NaN  66.98  Degraded
# 3        93HB06  27.858000  ...                NaN  15.18  Degraded
# 4        93HB07  27.850201  ...                NaN  63.30  Degraded
#
#    SpeciesRichness  AdjCountAbundance  ShannonDiversity  \
# 0              8.0              275.0              0.66
# 1              9.0             8175.0              0.29
# 2             53.0            19425.0              0.62
# 3             56.0            24225.0              0.65
# 4             12.0              350.0              0.56
#
#               DomSpecies1  DomSpecies1RelAbund               DomSpecies2  \
# 0      Paraprionospio sp.             0.272727      Sigambra tentaculata
# 1    Carazziella hobsonae             0.856269             ENTEROPNEUSTA
# 2     Kurtiella planulata             0.305019         Ampelisca holmesi
# 3         Mediomastus sp.             0.220846  Mediomastus cf. ambiseta
# 4  Turbonilla cf. conradi             0.142857       Prionospio perkinsi
#
#    DomSpecies2RelAbund
# 0             0.181818
# 1             0.055046
# 2             0.123552
# 3             0.187822
# 4             0.142857
#
# [5 rows x 254 columns]
